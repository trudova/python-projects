# %%
import pandas as pd
housing = pd.read_csv('kc_house_data.csv')
titanic = pd.read_csv('titanic.csv')
netflix = pd.read_csv('netflix_titles.csv', sep='|', index_col=0)

# %%
df= titanic.head()

# %%
df.sex
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
df.sex =='female'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
df[df.sex =='female']
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic[titanic.survived == 1]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %%
titanic[titanic['age']=='18']
# Out:
#       pclass  survived                                               name  \
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 198        1         1  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...
# 228        1         0         Penasco y Castellana, Mr. Victor de Satode
# 250        1         1                         Ryerson, Miss. Emily Borie
# 270        1         1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 289        1         1                                Taussig, Miss. Ruth
# 326        2         0                         Andrew, Mr. Edgardo Samuel
# 331        2         0                           Bailey, Mr. Percy Andrew
# 386        2         0                          Davies, Mr. Charles Henry
# 394        2         0                                Dibden, Mr. William
# 395        2         1                                Doling, Miss. Elsie
# 405        2         0                          Fahlstrom, Mr. Arne Jonas
# ...

# %%
titanic[titanic['pclass']==3]
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
titanic[titanic['pclass']!=3].pclass.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
housing[housing['price']<350000]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 6      1321400060  20140627T000000  257500.0         3       2.25
# 7      2008000270  20150115T000000  291850.0         3       1.50
# 8      2414600126  20150415T000000  229500.0         3       1.00
# ...           ...              ...       ...       ...        ...
# 21572  6056111067  20140707T000000  230000.0         3       1.75
# 21585  3832050760  20140828T000000  270000.0         3       2.50
# 21589  7570050450  20140910T000000  347500.0         3       2.50
# 21602   844000965  20140626T000000  224000.0         3       1.75
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
housing['bedrooms'].between(2,4)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 21608    True
# 21609    True
# 21610    True
# 21611    True
# 21612    True
# Name: bedrooms, Length: 21613, dtype: bool

# %%
housing[housing['bedrooms'].between(10,20)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# 13314        2500           2090      2008             0    98004  47.5861
# ...

# %%
netflix[netflix['country'].isin(['India', 'Russia'])]
# Out:
#      show_id     type                    title           director  \
# 153     s154  TV Show               Kid-E-Cats                NaN
# 522     s523  TV Show                    Larva                NaN
# 1880   s1881  TV Show              To the Lake   Pavel Kostomarov
# 2583   s2584  TV Show       Masha and the Bear                NaN
# 3577   s3578  TV Show           Better Than Us                NaN
# 4143   s4144  TV Show                   Sparta                NaN
# 5170   s5171  TV Show               The Method                NaN
# 5350   s5351  TV Show                   Fartsa                NaN
# 5355   s5356  TV Show                   Locust                NaN
# 6258   s6259  TV Show              Be-Be-Bears                NaN
# 6821   s6822    Movie  Gagarin: First in Space  Pavel Parkhomenko
# 7131   s7132  TV Show               JingleKids                NaN
# 8020   s8021  TV Show             Silver Spoon                NaN
# ...

# %%
netflix[netflix['country'].isin(['India','Russia'])].country.value_counts()
# Out:
# country
# India     972
# Russia     15
# Name: count, dtype: int64

# %%
netflix[netflix['rating'].isin(['R'])]['title'].value_counts()
# Out:
# title
# Safe House                  1
# Gothika                     1
# Green Room                  1
# Hamburger Hill              1
# Hangman                     1
#                            ..
# Freaks                      1
# W.E.                        1
# There Will Be Blood         1
# The Last Thing He Wanted    1
# Zombieland                  1
# Name: count, Length: 799, dtype: int64

# %%
survived = titanic.survived == 1
female =titanic.sex =='female'
titanic[ female & survived ]
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# ...      ...       ...                                                ...
# 1260       3         1                            Turja, Miss. Anna Sofia
# 1261       3         1                             Turkula, Mrs. (Hedwig)
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
housing
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
housing[(housing['bedrooms']>=3) & (housing['floors']>=2)& (housing['grade']>=10) & (housing['view']>=3)].sort_values('price')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 18848  7631800110  20140918T000000   380000.0         3       2.50
# 15006  9264000010  20140729T000000   535000.0         3       2.00
# 3204   4136980090  20150407T000000   537000.0         4       4.25
# 5387    587550470  20150429T000000   600000.0         3       2.75
# 6906    587550280  20140530T000000   625000.0         4       3.25
# ...           ...              ...        ...       ...        ...
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 18848         1980     17342     2.0           1     4  ...     10
# ...

# %%
titanic[~ female & ~ survived ]
# Out:
#       pclass  survived                                  name   sex   age  \
# 3          1         0  Allison, Mr. Hudson Joshua Creighton  male    30
# 7          1         0                Andrews, Mr. Thomas Jr  male    39
# 9          1         0               Artagaveytia, Mr. Ramon  male    71
# 10         1         0                Astor, Col. John Jacob  male    47
# 15         1         0                   Baumann, Mr. John D  male     ?
# ...      ...       ...                                   ...   ...   ...
# 1302       3         0                     Yousif, Mr. Wazli  male     ?
# 1303       3         0                 Yousseff, Mr. Gerious  male     ?
# 1306       3         0             Zakarian, Mr. Mapriededer  male  26.5
# 1307       3         0                   Zakarian, Mr. Ortin  male    27
# 1308       3         0                    Zimmerman, Mr. Leo  male    29
#
#       sibsp  parch    ticket     fare    cabin embarked boat body  \
# ...

# %%
netflix['director'].isna()
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 8802    False
# 8803     True
# 8804    False
# 8805    False
# 8806    False
# Name: director, Length: 8807, dtype: bool

# %%
netflix[netflix['director'].isna()]
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water      NaN
# 3         s4  TV Show                Jailbirds New Orleans      NaN
# 4         s5  TV Show                         Kota Factory      NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V      NaN
# 8796   s8797  TV Show                           Yunus Emre      NaN
# 8797   s8798  TV Show                            Zak Storm      NaN
# 8800   s8801  TV Show                   Zindagi Gulzar Hai      NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
netflix[netflix['director'].notna()]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
titanic[(titanic['sex']=='female') & (titanic['survived']==1)]
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# ...      ...       ...                                                ...
# 1260       3         1                            Turja, Miss. Anna Sofia
# 1261       3         1                             Turkula, Mrs. (Hedwig)
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
titanic[titanic['sex']=='female'].survived.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
housing[housing['price']>4000000].zipcode.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='zipcode'>
