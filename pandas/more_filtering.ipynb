# %%
import pandas as pd
books = pd.read_csv('bestsellers.csv')
books
housing = pd.read_csv('kc_house_data.csv')
titanic = pd.read_csv('titanic.csv')
netflix = pd.read_csv('netflix_titles.csv', sep='|', index_col=0)
coin = pd.read_csv("coin_Bitcoin.csv")
hc = pd.read_csv('world-happiness-report-2021.csv')

# %%
books[books['Author']=='George Orwell']
# Out:
#                      Name         Author  User Rating  Reviews  Price  Year  \
# 3  1984 (Signet Classics)  George Orwell          4.7    21424      6  2017
#
#      Genre
# 3  Fiction

# %%
books[books['Price']<10]
# Out:
#                                                   Name           Author  \
# 0                        10-Day Green Smoothie Cleanse         JJ Smith
# 3                               1984 (Signet Classics)    George Orwell
# 8        A Higher Loyalty: Truth, Lies, and Leadership      James Comey
# 9                            A Man Called Ove: A Novel  Fredrik Backman
# 10                           A Man Called Ove: A Novel  Fredrik Backman
# ..                                                 ...              ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
books[books['Price'].between(50,60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %%
books[(books['User Rating'] ==4.9) & (books['Genre']=='Non Fiction')]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 174                       Humans of New York : Stories     Brandon Stanton
# 187  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 188  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 189  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 190  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 191  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 192  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 244                        Obama: An Intimate Portrait          Pete Souza
# 431                                 The Magnolia Story         Chip Gaines
# 521                             Unfreedom of the Press       Mark R. Levin
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
books12= books[(books['Year'] ==2012) &(books['Genre'] == 'Fiction')]
books12.sort_values('Reviews', ascending=False).head(5)
# Out:
#                                                   Name           Author  \
# 135                                          Gone Girl    Gillian Flynn
# 365                             The Fault in Our Stars       John Green
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 409                          The Hunger Games (Book 1)  Suzanne Collins
# 238                      Mockingjay (The Hunger Games)  Suzanne Collins
#
#      User Rating  Reviews  Price  Year    Genre
# 135          4.0    57271     10  2012  Fiction
# 365          4.7    50482     13  2012  Fiction
# 106          3.8    47265     14  2012  Fiction
# 409          4.7    32122      8  2012  Fiction
# 238          4.5    26741      8  2012  Fiction

# %%
books[books['User Rating']<4.5]['Author'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='Author'>

# %%
hc.set_index('Country name', inplace=True)

# %%
coin.drop(labels='Symbol', axis=1)
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
coin.drop(labels=['Symbol','Name','SNo'], axis=1)
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
coin.drop(columns=['Symbol','Name','SNo'])
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
hc.drop(['Finland','Denmark'])
#hc.drop(hc.index[0:3])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# ...

# %%
titanic['species'] ='humane'

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
housing.insert(1,'county', 'happy county')

# %%
housing
# Out:
#                id        county             date     price  bedrooms  \
# 0      7129300520  happy county  20141013T000000  221900.0         3
# 1      6414100192  happy county  20141209T000000  538000.0         3
# 2      5631500400  happy county  20150225T000000  180000.0         2
# 3      2487200875  happy county  20141209T000000  604000.0         4
# 4      1954400510  happy county  20150218T000000  510000.0         3
# ...           ...           ...              ...       ...       ...
# 21608   263000018  happy county  20140521T000000  360000.0         3
# 21609  6600060120  happy county  20150223T000000  400000.0         4
# 21610  1523300141  happy county  20140623T000000  402101.0         2
# 21611   291310100  happy county  20150116T000000  400000.0         3
# 21612  1523300157  happy county  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# ...

# %%
housing.insert(0,'price pure bedroom', (housing['price'])/(housing['bedrooms']))

# %%
housing
# Out:
#        price pure bedroom          id             date     price  bedrooms  \
# 0            73966.666667  7129300520  20141013T000000  221900.0         3
# 1           179333.333333  6414100192  20141209T000000  538000.0         3
# 2            90000.000000  5631500400  20150225T000000  180000.0         2
# 3           151000.000000  2487200875  20141209T000000  604000.0         4
# 4           170000.000000  1954400510  20150218T000000  510000.0         3
# ...                   ...         ...              ...       ...       ...
# 21608       120000.000000   263000018  20140521T000000  360000.0         3
# 21609       100000.000000  6600060120  20150223T000000  400000.0         4
# 21610       201050.500000  1523300141  20140623T000000  402101.0         2
# 21611       133333.333333   291310100  20150116T000000  400000.0         3
# 21612       162500.000000  1523300157  20141015T000000  325000.0         2
#
# ...

# %%
(housing['bathrooms'])
# Out:
# 0        1.00
# 1        2.25
# 2        1.00
# 3        3.00
# 4        2.00
#          ...
# 21608    2.50
# 21609    2.50
# 21610    0.75
# 21611    2.50
# 21612    0.75
# Name: bathrooms, Length: 21613, dtype: float64

# %%
titanic['sibsp'] + titanic['parch']
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Length: 1309, dtype: int64

# %%
titanic['num relatives'] = (titanic['sibsp'] + titanic['parch'])

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sort_values('num relatives', ascending=False)
# Out:
#       pclass  survived                                    name     sex age  \
# 1177       3         0                     Sage, Mr. Frederick    male   ?
# 1179       3         0                   Sage, Mr. John George    male   ?
# 1173       3         0            Sage, Miss. Constance Gladys  female   ?
# 1170       3         0              Sage, Master. Thomas Henry    male   ?
# 1172       3         0                         Sage, Miss. Ada  female   ?
# ...      ...       ...                                     ...     ...  ..
# 598        2         1                    Wright, Miss. Marion  female  26
# 599        2         0  Yrois, Miss. Henriette ('Mrs Harbeck')  female  24
# 600        3         0                     Abbing, Mr. Anthony    male  42
# 604        3         1             Abelseth, Miss. Karen Marie  female  16
# 1308       3         0                      Zimmerman, Mr. Leo    male  29
#
#       sibsp  parch     ticket   fare cabin embarked boat body  \
# ...

# %%
notalong=titanic[(titanic['survived']==1) & (titanic['num relatives']>0)].sort_values('num relatives', ascending=False)

# %%
notalong
# Out:
#       pclass  survived                                               name  \
# 646        3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 625        3         1                    Andersson, Miss. Erna Alexandra
# 641        3         1                  Asplund, Master. Edvin Rojj Felix
# 643        3         1                     Asplund, Miss. Lillian Gertrud
# 111        1         1                     Fortune, Miss. Alice Elizabeth
# ...      ...       ...                                                ...
# 176        1         1                  Kenyon, Mrs. Frederick R (Marion)
# 501        2         1                  Mellinger, Miss. Madeleine Violet
# 502        2         1          Mellinger, Mrs. (Elizabeth Anne Maidment)
# 513        2         1                Nasser, Mrs. Nicholas (Adele Achem)
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex age  sibsp  parch   ticket     fare        cabin embarked boat  \
# ...

# %%
housing['price_persqft']= housing['price']/housing['sqft_lot']

# %%
housing
# Out:
#        price pure bedroom          id             date     price  bedrooms  \
# 0            73966.666667  7129300520  20141013T000000  221900.0         3
# 1           179333.333333  6414100192  20141209T000000  538000.0         3
# 2            90000.000000  5631500400  20150225T000000  180000.0         2
# 3           151000.000000  2487200875  20141209T000000  604000.0         4
# 4           170000.000000  1954400510  20150218T000000  510000.0         3
# ...                   ...         ...              ...       ...       ...
# 21608       120000.000000   263000018  20140521T000000  360000.0         3
# 21609       100000.000000  6600060120  20150223T000000  400000.0         4
# 21610       201050.500000  1523300141  20140623T000000  402101.0         2
# 21611       133333.333333   291310100  20150116T000000  400000.0         3
# 21612       162500.000000  1523300157  20141015T000000  325000.0         2
#
# ...

# %%
housing.sort_values('price_persqft', ascending=False)
# Out:
#        price pure bedroom          id             date      price  bedrooms  \
# 3452        617285.000000  2559950110  20150422T000000  1234570.0         2
# 15743       175000.000000  9828702895  20141022T000000   700000.0         4
# 18010       247333.333333  7234601198  20140604T000000   742000.0         3
# 15679       462500.000000  5026900235  20140911T000000  1850000.0         4
# 20567       350000.000000  6926700654  20140921T000000   700000.0         2
# ...                   ...         ...              ...        ...       ...
# 4540        183333.333333  2522029039  20140929T000000   550000.0         3
# 2757         76666.666667  3520069033  20140623T000000   230000.0         3
# 7647        108500.000000  2623069031  20140521T000000   542500.0         5
# 1719        175000.000000  1020069017  20150327T000000   700000.0         4
# 17319        95000.000000  3326079016  20150504T000000   190000.0         2
#
# ...

# %%
coin.set_index('Date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/7f/dl3vc7955kg50492_1mlc6w40000gn/T/ipykernel_99416/3921823441.py in ?()
# ----> 1 coin.set_index('Date', inplace=True)
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Date'] are in the columns"

# %%
coin.drop(columns=['SNo','Name','Symbol'])
# Out:
#                              High           Low          Open         Close  \
# Date
# 2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993
# 2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000
# 2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998
# 2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999
# 2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000
# ...                           ...           ...           ...           ...
# 2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590
# 2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362  34668.548402
# 2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866  35287.779766
# 2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430  33746.002456
# 2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655  34235.193451
#
#                            Volume     Marketcap
# ...

# %%
jbt= pd.read_csv('JoeBidenTweets.csv')

# %%
jbt.set_index('id',inplace=True)

# %%
jbt.drop(columns='url')
# Out:
#                        id         timestamp  \
# 0               361388562  2007-10-24 22:45
# 1               543984392  2007-12-29 15:35
# 2      189287227321356289  2012-04-09 09:42
# 3      189287350034104320  2012-04-09 09:43
# 4      189339650610036736  2012-04-09 13:11
# ...                   ...               ...
# 6059  1322865972819251200  2020-11-01 11:40
# 6060  1322871257902145536  2020-11-01 12:01
# 6061  1322876039144636417  2020-11-01 12:20
# 6062  1322881072363917312  2020-11-01 12:40
# 6063  1322886357535150081  2020-11-01 13:01
#
#                                                   tweet  replies  retweets  \
# 0     Tune in 11:30 ET tomorrow for a live webcast o...       19         5
# 1     Iowans, there's a good chance there's a Biden ...       13        16
# 2     We're excited to announce that @JoeBiden is be...       21        82
# 3     Campaign staff will run this account to keep y...      144        76
# ...

# %%
jbt.drop(361388562)
# Out:
#                             timestamp  \
# id
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# 189343279140184065   2012-04-09 13:25
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# 189343279140184065   https://twitter.com/JoeBiden/status/1893432791...
# ...

# %%
jbt['user']='JoeBiden'

# %%
jbt
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
jbt['ratio'] = jbt['replies']/jbt['retweets']

# %%
jbt.sort_values('ratio', ascending=False)
# Out:
#                             timestamp  \
# id
# 232971730119950338   2012-08-07 22:49
# 1200882191875465216  2019-11-30 21:00
# 1150774078233387008  2019-07-15 14:28
# 1186989582182694922  2019-10-23 12:55
# 1189327302733238272  2019-10-29 23:45
# ...                               ...
# 202779651985256450   2012-05-16 15:16
# 190826443322818561   2012-04-13 15:39
# 225726112607645697   2012-07-18 22:57
# 195176336346710016   2012-04-25 15:43
# 194450021532442628   2012-04-23 15:37
#
#                                                                    url  \
# id
# 232971730119950338   https://twitter.com/JoeBiden/status/2329717301...
# 1200882191875465216  https://twitter.com/JoeBiden/status/1200882191...
# 1150774078233387008  https://twitter.com/JoeBiden/status/1150774078...
# 1186989582182694922  https://twitter.com/JoeBiden/status/1186989582...
# 1189327302733238272  https://twitter.com/JoeBiden/status/1189327302...
# ...

# %%
hc.set_index('Country name', inplace=True)

# %%
hc.rename(columns={'Regional indicator': 'Regional'})
# Out:
#     Country name            Regional  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
hc.rename(index={'Finland': 'frozen rock'})
# Out:
#               Regional indicator  Ladder score  \
# Country name
# frozen rock       Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# frozen rock                            0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
titanic.sex.replace('female', 'F', inplace=True)

# %%
titanic.sex.replace(['female', 'male'],['F','M'])
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: object

# %%
hc.loc[['Denmark', 'Finland', 'Switzerland','Russia'],['Freedom to make life choices','Perceptions of corruption']]
# Out:
#               Freedom to make life choices  Perceptions of corruption
# Country name
# Denmark                              0.946                      0.179
# Finland                              0.949                      0.186
# Switzerland                          0.919                      0.292
# Russia                               0.718                      0.845

# %%
hc.loc[['Denmark', 'Finland', 'Switzerland','Russia'],['Regional indicator']] = 'Scandinavia'

# %%
hc
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland              Scandinavia         7.842
# Denmark              Scandinavia         7.620
# Switzerland          Scandinavia         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
hc.loc[['Denmark', 'Finland', 'Switzerland','Russia'],['Regional indicator', 'is_cold']] = ['northen',True]

# %%
hc
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland                  northen         7.842
# Denmark                  northen         7.620
# Switzerland              northen         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
high_quality= housing['grade']>12
good_view= housing['view']>=4
housing[high_quality & good_view]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 14556  2303900035  20140611T000000  2888000.0         5       6.25
# 19017  2303900100  20140911T000000  3800000.0         3       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9254          9890     31374     2.0           0     4  ...     13
# 14556         8670     64033     2.0           0     4  ...     13
# 19017         5510     35000     2.0           0     4  ...     13
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 9254         8860           1030      2001             0    98039  47.6305
# 14556        6120           2550      1965          2003    98177  47.7295
# 19017        4910            600      1997             0    98177  47.7296
#
#           long  sqft_living15  sqft_lot15
# 9254  -122.240           4540       42730
# ...

# %%
housing['luxury'] ='normal'

# %%
housing.loc[high_quality & good_view,['luxury']]= 'ultra luxury'

# %%
housing.luxury.value_counts()
# Out:
# luxury
# normal          21610
# ultra luxury        3
# Name: count, dtype: int64

# %%
netflix.set_index('show_id', inplace=True)

# %%
netflix.loc['s2202', 'director'] = 'Liv Bradford'

# %%
netflix.loc['s2202']
# Out:
# type                                                      TV Show
# title                                               Last Chance U
# director                                             Liv Bradford
# cast            John Franklin III, DJ Law, Buddy Stephens, Bri...
# country                                             United States
# date_added                                          July 28, 2020
# release_year                                                 2020
# rating                                                      TV-MA
# duration                                                5 Seasons
# listed_in                                              Docuseries
# description     In a docuseries set at one of NCAA football's ...
# Name: s2202, dtype: object

# %%
netflix.loc[['s8803','s1'],'duration'] = 'gone too soon'

# %%
netflix.rename(columns={'rating': 'how good'}, inplace=True)

# %%
netflix
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix[netflix['title']=='Evil']
# Out:
#             type title director  \
# show_id
# s1907    TV Show  Evil      NaN
#
#                                                       cast        country  \
# show_id
# s1907    Katja Herbers, Mike Colter, Aasif Mandvi, Mich...  United States
#
#               date_added  release_year how good  duration  listed_in  \
# show_id
# s1907    October 1, 2020          2019    TV-14  1 Season  TV Dramas
#
#                                                description
# show_id
# s1907    A forensic psychologist partners with a Cathol...

# %%
netflix.rename({'s1907': 's666'}, inplace=True)

# %%
netflix[netflix['title']=='Evil']
# Out:
#             type title director  \
# show_id
# s666     TV Show  Evil      NaN
#
#                                                       cast        country  \
# show_id
# s666     Katja Herbers, Mike Colter, Aasif Mandvi, Mich...  United States
#
#               date_added  release_year how good  duration  listed_in  \
# show_id
# s666     October 1, 2020          2019    TV-14  1 Season  TV Dramas
#
#                                                description
# show_id
# s666     A forensic psychologist partners with a Cathol...

# %%
netflix['how good'].replace(['NR', 'UR'], 'No rating', inplace=True)
# Out:
# /var/folders/7f/dl3vc7955kg50492_1mlc6w40000gn/T/ipykernel_99416/976788552.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   netflix['how good'].replace(['NR', 'UR'], 'No rating', inplace=True)

# %%
netflix['how good'].value_counts()
# Out:
# how good
# TV-MA        3207
# TV-14        2160
# TV-PG         863
# R             799
# PG-13         490
# TV-Y7         334
# TV-Y          307
# PG            287
# TV-G          220
# No rating      83
# G              41
# TV-Y7-FV        6
# NC-17           3
# 74 min          1
# 84 min          1
# 66 min          1
# Name: count, dtype: int64

# %%
netflix['is_fave'] = False

# %%
faves=['Dark', 'Big Mouth']
netflix.loc[netflix['title'].isin(faves) , 'is_fave']=True

# %%
netflix['is_fave'].value_counts()
# Out:
# is_fave
# False    8805
# True        2
# Name: count, dtype: int64

# %%
titanic['age'].replace(['?'], [None], inplace=True)
# Out:
# /var/folders/7f/dl3vc7955kg50492_1mlc6w40000gn/T/ipykernel_99416/3065196104.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['age'].replace(['?'], [None], inplace=True)

# %%
titanic.age.value_counts(dropna=False)
# Out:
# age
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: count, Length: 99, dtype: int64

# %%
titanic['age'].astype('float')
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
titanic['age'] =titanic['age'].astype('float')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
titanic['age'].mean()
# Out:
# 29.8811345124283
