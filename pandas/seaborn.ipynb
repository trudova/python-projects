# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
tips= sb.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
penguins = sb.load_dataset('penguins')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sb.set_theme()

# %%
sb.scatterplot(tips, x='total_bill', y='tip', hue='smoker', style='sex')
plt.show()

# %%
sb.scatterplot(tips, x='total_bill', y='tip', hue='sex', style='sex', size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sb.scatterplot(tips, x='total_bill', y='tip', hue='sex', size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
flights= sb.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sb.lineplot(flights, x='month', y='passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sb.lineplot(data=flights, x='year', y='passengers') #taking the ave of all months
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sb.lineplot(data=flights, x='year', y='passengers', estimator='sum')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sb.lineplot(data=flights, x='year', y='passengers', estimator='sum', hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
taxis = sb.load_dataset('taxis', parse_dates=['pickup','dropoff'])

# %%
taxis
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
taxis['hour'] = taxis['pickup'].dt.hour

# %%
sb.lineplot(taxis, x='hour', y='total', hue='payment')
# Out:
# <Axes: xlabel='hour', ylabel='total'>

# %%
sb.lineplot(taxis, x='hour', y='total', hue='payment', ci=None, style='color')
# Out:
# /var/folders/7f/dl3vc7955kg50492_1mlc6w40000gn/T/ipykernel_70085/459255340.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sb.lineplot(taxis, x='hour', y='total', hue='payment', ci=None, style='color')
# <Axes: xlabel='hour', ylabel='total'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sb.relplot(data=tips, x='total_bill',y='tip', kind='scatter', col='sex', hue='smoker')

# %%
sb.relplot(data=tips, x='total_bill',y='tip', kind='scatter', col='sex', hue='smoker', row='time')

# %%
taxis
sb.relplot(data=taxis, x='hour', y='total', kind='line', col='pickup_borough',
           hue='payment',
          row='dropoff_borough')

# %%
plt.figure(figsize=(11,5))
sb.lineplot(data=flights, x='year', y='passengers', estimator='sum', hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sb.relplot(data=tips, x='total_bill',
           y='tip',
           kind='scatter',
           col='sex',
           hue='smoker',
           height=3,
           aspect=1.5
           
          )

# %%
sb.histplot(data=tips, x='tip', hue='time',multiple='dodge')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.histplot(data=tips, x='tip', hue='time',multiple='stack')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sb.histplot(data=penguins, x='body_mass_g', bins=20)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sb.histplot(data=penguins, x='body_mass_g', bins=20, hue='species', multiple='stack')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sb.histplot(data=penguins, x='body_mass_g', bins=20, hue='species', multiple='stack', element='step')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sb.histplot(data=tips, x='tip', kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.kdeplot(penguins, x='body_mass_g', hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sb.kdeplot(penguins, x='body_mass_g', hue='species', bw_adjust=0.5)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sb.histplot(penguins, x='body_mass_g', y='flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sb.kdeplot(penguins, x='body_mass_g', y='flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sb.kdeplot(penguins, x='body_mass_g', y='flipper_length_mm', hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sb.histplot(penguins, x='body_mass_g', y='flipper_length_mm', hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sb.kdeplot(tips, x='total_bill')
sb.rugplot(tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sb.scatterplot(tips, x='total_bill', y='tip')
sb.rugplot(tips, x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sb.displot(kind='hist', 
           data=penguins,
           x='body_mass_g',
           height=3, 
           aspect=1,
           col='species',
           hue='sex'
    
          )

# %%
sb.displot(data=tips, kind='kde',x='total_bill', y='tip', col='time',rug=True)

# %%
sb.displot(tips, kind='kde', x='tip', col='time',rug=True)

# %%
sb.countplot(penguins,x='species', hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
titanic = pd.read_csv('titanic.csv')

# %%
sb.countplot(titanic, x='survived', hue='sex')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
taxis
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sb.scatterplot(taxis, x='pickup_borough', y='total')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sb.stripplot(taxis, x='pickup_borough', y='total')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
trip_sample= taxis.nlargest(600, 'total')

# %%
plt.figure(figsize=(13,6))
sb.swarmplot(trip_sample, x='pickup_borough', y='total')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
titanic = sb.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sb.stripplot(titanic, x='pclass', y='age')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
plt.figure(figsize=(13,6))
sb.swarmplot(titanic, x='pclass', y='age', hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sb.boxplot(titanic, x='age', hue='survived')
# Out:
# <Axes: xlabel='age'>

# %%
sb.boxplot(taxis, x='pickup_borough', y='tip')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
sb.boxplot(taxis, x='pickup_borough', y='tip',whis=0.5)
# Out:
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
sb.set_style('darkgrid')

# %%
sb.boxplot(titanic, x='pclass', y='age', hue='survived')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sb.boxplot(titanic, x='sex', y='age', hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.boxenplot(taxis, x='pickup_borough', y='total')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sb.violinplot(titanic, x='age')
sb.rugplot(titanic, x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sb.violinplot(titanic, x='pclass', y='age', hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sb.violinplot(titanic, x='pclass', y='age', hue='sex', split=True)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sb.barplot(taxis, x='pickup_borough', y='total')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sb.barplot(taxis, x='pickup_borough', y='total', estimator=sum, hue='color')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sb.violinplot(taxis, x='pickup_borough', y='total', hue='color')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sb.catplot(titanic, x='sex', y='age', kind='bar', col='pclass')

# %%
sb.catplot(titanic, x='sex', y='age', kind='bar', col='pclass', hue='survived')

# %%
sb.catplot(titanic, kind='bar',x='who', y='survived', col='pclass')

# %%
sb.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}
