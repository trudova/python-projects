# %%
import pandas as pd

# %%
bestsellers = pd.read_csv('bestsellers.csv')

# %%
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
bestsellers.Name
# Out:
# 0                          10-Day Green Smoothie Cleanse
# 1                                      11/22/63: A Novel
# 2                12 Rules for Life: An Antidote to Chaos
# 3                                 1984 (Signet Classics)
# 4      5,000 Awesome Facts (About Everything!) (Natio...
#                              ...
# 545         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, Length: 550, dtype: object

# %%
bestsellers['User Rating']
# Out:
# 0      4.7
# 1      4.6
# 2      4.7
# 3      4.7
# 4      4.8
#       ...
# 545    4.9
# 546    4.7
# 547    4.7
# 548    4.7
# 549    4.7
# Name: User Rating, Length: 550, dtype: float64

# %%
bestsellers.Author.head(8)
# Out:
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# 5         George R. R. Martin
# 6         George R. R. Martin
# 7                 Amor Towles
# Name: Author, dtype: object

# %%
bestsellers['Genre'].unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %%
bestsellers['Author'].nunique()
# Out:
# 248

# %%
bestsellers['Price'].mean()
# Out:
# 13.1

# %%
bestsellers['Price'].max()
# Out:
# 105

# %%
bestsellers['Price'].nlargest(10)
# Out:
# 69     105
# 70     105
# 473     82
# 151     54
# 346     53
# 159     52
# 271     46
# 272     46
# 273     46
# 274     46
# Name: Price, dtype: int64

# %%
bestsellers['Name'].value_counts().head(3)
# Out:
# Name
# Publication Manual of the American Psychological Association, 6th Edition    10
# StrengthsFinder 2.0                                                           9
# Oh, the Places You'll Go!                                                     8
# Name: count, dtype: int64

# %%
bestsellers[['Author','User Rating']]
# Out:
#                        Author  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ..                        ...          ...
# 545               Jeff Kinney          4.9
# 546               Jen Sincero          4.7
# 547               Jen Sincero          4.7
# 548               Jen Sincero          4.7
# 549               Jen Sincero          4.7
#
# [550 rows x 2 columns]

# %%
bestsellers[['Author','User Rating']].value_counts()
# Out:
# Author                              User Rating
# Jeff Kinney                         4.8            10
# American Psychological Association  4.5            10
# Gallup                              4.0             9
# Rick Riordan                        4.8             9
# Dr. Seuss                           4.9             8
#                                                    ..
# Ken Follett                         4.5             1
# Kevin Kwan                          4.3             1
# Khaled Hosseini                     4.3             1
# DK                                  4.5             1
# Jeff Kinney                         4.9             1
# Name: count, Length: 301, dtype: int64

# %%
bestsellers['Genre'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
bestsellers['Author'].value_counts().head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='Author'>

# %%
bestsellers[['Name','User Rating']].head(7).plot( x='Name', y='User Rating',kind='bar',)
# Out:
# <Axes: xlabel='Name'>

# %% [markdown]
# # Indexes and sorting

# %%
coin = pd.read_csv("coin_Bitcoin.csv")
coin
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
coin.set_index('Date')
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
coin
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
coin.set_index("Date", inplace=True)

# %%
coin
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
coin.index
# Out:
# Index(['2013-04-29 23:59:59', '2013-04-30 23:59:59', '2013-05-01 23:59:59',
#        '2013-05-02 23:59:59', '2013-05-03 23:59:59', '2013-05-04 23:59:59',
#        '2013-05-05 23:59:59', '2013-05-06 23:59:59', '2013-05-07 23:59:59',
#        '2013-05-08 23:59:59',
#        ...
#        '2021-06-27 23:59:59', '2021-06-28 23:59:59', '2021-06-29 23:59:59',
#        '2021-06-30 23:59:59', '2021-07-01 23:59:59', '2021-07-02 23:59:59',
#        '2021-07-03 23:59:59', '2021-07-04 23:59:59', '2021-07-05 23:59:59',
#        '2021-07-06 23:59:59'],
#       dtype='object', name='Date', length=2991)

# %%
hc = pd.read_csv('world-happiness-report-2021.csv')

# %%
hc
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
hc['Healthy life expectancy']
# Out:
# 0      72.000
# 1      72.700
# 2      74.400
# 3      73.000
# 4      72.400
#         ...
# 144    48.700
# 145    59.269
# 146    61.400
# 147    56.201
# 148    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
hc.set_index('Country name', inplace=True)

# %%
hc['Healthy life expectancy'].head(20)
# Out:
# Country name
# Finland           72.000
# Denmark           72.700
# Switzerland       74.400
# Iceland           73.000
# Netherlands       72.400
# Norway            73.300
# Sweden            72.700
# Luxembourg        72.600
# New Zealand       73.400
# Austria           73.300
# Australia         73.900
# Israel            73.503
# Germany           72.500
# Canada            73.800
# Ireland           72.400
# Costa Rica        71.400
# United Kingdom    72.500
# Czech Republic    70.807
# United States     68.200
# Belgium           72.199
# Name: Healthy life expectancy, dtype: float64

# %%
hc['Healthy life expectancy'].head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='Country name'>

# %%
hc2 = pd.read_csv('world-happiness-report-2021.csv', index_col=0) #replasing the index right in the import 
hc2
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
hc.sort_values('Healthy life expectancy')
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Chad                       Sub-Saharan Africa         4.355
# Lesotho                    Sub-Saharan Africa         3.512
# Nigeria                    Sub-Saharan Africa         4.759
# Ivory Coast                Sub-Saharan Africa         5.306
# Swaziland                  Sub-Saharan Africa         4.308
# ...                                       ...           ...
# Switzerland                    Western Europe         7.571
# Spain                          Western Europe         6.491
# Japan                               East Asia         5.940
# Hong Kong S.A.R. of China           East Asia         5.477
# Singapore                      Southeast Asia         6.377
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Chad                                                0.094         4.540
# ...

# %%
hc.sort_values('Healthy life expectancy', ascending=False).head(20)
# Out:
#                                      Regional indicator  Ladder score  \
# Country name
# Singapore                                Southeast Asia         6.377
# Hong Kong S.A.R. of China                     East Asia         5.477
# Japan                                         East Asia         5.940
# Spain                                    Western Europe         6.491
# Switzerland                              Western Europe         7.571
# France                                   Western Europe         6.690
# South Korea                                   East Asia         5.845
# Australia                         North America and ANZ         7.183
# Cyprus                                   Western Europe         6.223
# North Cyprus                             Western Europe         5.536
# Canada                            North America and ANZ         7.103
# Italy                                    Western Europe         6.483
# ...

# %%
hc.sort_values('Healthy life expectancy', ascending=False, inplace=True)

# %%
hc
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Singapore                      Southeast Asia         6.377
# Hong Kong S.A.R. of China           East Asia         5.477
# Japan                               East Asia         5.940
# Spain                          Western Europe         6.491
# Switzerland                    Western Europe         7.571
# ...                                       ...           ...
# Swaziland                  Sub-Saharan Africa         4.308
# Ivory Coast                Sub-Saharan Africa         5.306
# Nigeria                    Sub-Saharan Africa         4.759
# Lesotho                    Sub-Saharan Africa         3.512
# Chad                       Sub-Saharan Africa         4.355
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Singapore                                           0.043         6.460
# ...

# %%
hc.head(30)
# Out:
#                                      Regional indicator  Ladder score  \
# Country name
# Singapore                                Southeast Asia         6.377
# Hong Kong S.A.R. of China                     East Asia         5.477
# Japan                                         East Asia         5.940
# Spain                                    Western Europe         6.491
# Switzerland                              Western Europe         7.571
# France                                   Western Europe         6.690
# South Korea                                   East Asia         5.845
# Australia                         North America and ANZ         7.183
# Cyprus                                   Western Europe         6.223
# North Cyprus                             Western Europe         5.536
# Canada                            North America and ANZ         7.103
# Italy                                    Western Europe         6.483
# ...

# %%
houses = pd.read_csv('kc_house_data.csv')
titanic = pd.read_csv('titanic.csv')

# %%
houses.sort_values('price', ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
houses.sort_values(['bedrooms','bathrooms'], ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# ...           ...              ...        ...       ...        ...
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
titanic.sort_values('name')
# Out:
#       pclass  survived                                           name     sex  \
# 600        3         0                            Abbing, Mr. Anthony    male
# 601        3         0                  Abbott, Master. Eugene Joseph    male
# 602        3         0                    Abbott, Mr. Rossmore Edward    male
# 603        3         1               Abbott, Mrs. Stanton (Rosa Hunt)  female
# 604        3         1                    Abelseth, Miss. Karen Marie  female
# ...      ...       ...                                            ...     ...
# 392        2         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female
# 1262       3         0            van Billiard, Master. James William    male
# 1263       3         0              van Billiard, Master. Walter John    male
# 1264       3         0                van Billiard, Mr. Austin Blyler    male
# 1268       3         0                    van Melkebeke, Mr. Philemon    male
#
# ...

# %%
titanic.sort_values('name', key= lambda col:col.str.lower())
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
hc.sort_index()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
titanic.pclass.value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
titanic.pclass.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
titanic.pclass.value_counts().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
houses.bedrooms.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses.bedrooms.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %%
hc.loc['Japan']
# Out:
# Regional indicator                            East Asia
# Ladder score                                       5.94
# Standard error of ladder score                     0.04
# upperwhisker                                       6.02
# lowerwhisker                                      5.861
# Logged GDP per capita                            10.611
# Social support                                    0.884
# Healthy life expectancy                            75.1
# Freedom to make life choices                      0.796
# Generosity                                       -0.258
# Perceptions of corruption                         0.638
# Ladder score in Dystopia                           2.43
# Explained by: Log GDP per capita                  1.389
# Explained by: Social support                      0.949
# Explained by: Healthy life expectancy             0.838
# Explained by: Freedom to make life choices        0.504
# Explained by: Generosity                           0.02
# ...

# %%
hc.loc[['Japan']]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Japan                 East Asia          5.94                            0.04
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Japan                 6.02         5.861                 10.611
#
#               Social support  Healthy life expectancy  \
# Country name
# Japan                  0.884                     75.1
#
#               Freedom to make life choices  Generosity  \
# Country name
# Japan                                0.796      -0.258
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Japan                             0.638                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Japan                                    1.389                         0.949
#
#               Explained by: Healthy life expectancy  \
# ...

# %%
hc.loc[['Canada', 'United States']]
# Out:
#                   Regional indicator  Ladder score  \
# Country name
# Canada         North America and ANZ         7.103
# United States  North America and ANZ         6.951
#
#                Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Canada                                  0.042         7.185         7.021
# United States                           0.049         7.047         6.856
#
#                Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Canada                        10.776           0.926                     73.8
# United States                 11.023           0.920                     68.2
#
#                Freedom to make life choices  Generosity  \
# Country name
# Canada                                0.915       0.089
# United States                         0.837       0.098
#
#                Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
titanic.loc[[1,4,7]]
# Out:
#    pclass  survived                                             name     sex  \
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
#
#       age  sibsp  parch  ticket    fare    cabin embarked boat body  \
# 1  0.9167      1      2  113781  151.55  C22 C26        S   11    ?
# 4      25      1      2  113781  151.55  C22 C26        S    ?    ?
# 7      39      0      0  112050       0      A36        S    ?    ?
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 7                      Belfast, NI

# %%
titanic[5:10]
# Out:
#    pclass  survived                                           name     sex  \
# 5       1         1                            Anderson, Mr. Harry    male
# 6       1         1              Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                         Andrews, Mr. Thomas Jr    male
# 8       1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                        Artagaveytia, Mr. Ramon    male
#
#   age  sibsp  parch    ticket     fare cabin embarked boat body  \
# 5  48      0      0     19952    26.55   E12        S    3    ?
# 6  63      1      0     13502  77.9583    D7        S   10    ?
# 7  39      0      0    112050        0   A36        S    ?    ?
# 8  53      2      0     11769  51.4792  C101        S    D    ?
# 9  71      0      0  PC 17609  49.5042     ?        C    ?   22
#
#              home.dest
# 5         New York, NY
# 6           Hudson, NY
# 7          Belfast, NI
# 8  Bayside, Queens, NY
# ...

# %%
titanic[5:20:2]
# Out:
#     pclass  survived                                               name  \
# 5        1         1                                Anderson, Mr. Harry
# 7        1         0                             Andrews, Mr. Thomas Jr
# 9        1         0                            Artagaveytia, Mr. Ramon
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 13       1         1                       Barber, Miss. Ellen 'Nellie'
# 15       1         0                                Baumann, Mr. John D
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 19       1         0                               Beattie, Mr. Thomson
#
#        sex age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# 5     male  48      0      0     19952     26.55      E12        S    3    ?
# 7     male  39      0      0    112050         0      A36        S    ?    ?
# 9     male  71      0      0  PC 17609   49.5042        ?        C    ?   22
# ...

# %%
hc.iloc[[0]]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Singapore        Southeast Asia         6.377                           0.043
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Singapore             6.46         6.293                 11.488
#
#               Social support  Healthy life expectancy  \
# Country name
# Singapore              0.915                   76.953
#
#               Freedom to make life choices  Generosity  \
# Country name
# Singapore                            0.927      -0.018
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Singapore                         0.082                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Singapore                                1.695                         1.019
#
#               Explained by: Healthy life expectancy  \
# ...

# %%
hc.iloc[30:40]
# Out:
#                                     Regional indicator  Ladder score  \
# Country name
# Costa Rica                 Latin America and Caribbean         7.069
# Czech Republic              Central and Eastern Europe         6.965
# Croatia                     Central and Eastern Europe         5.882
# Maldives                                    South Asia         5.198
# Chile                      Latin America and Caribbean         6.172
# Poland                      Central and Eastern Europe         6.166
# Panama                     Latin America and Caribbean         6.180
# Taiwan Province of China                     East Asia         6.584
# China                                        East Asia         5.339
# Bahrain                   Middle East and North Africa         6.647
#
#                           Standard error of ladder score  upperwhisker  \
# Country name
# Costa Rica                                         0.056         7.179
# ...

# %%
houses.loc[3:6,['price', 'bedrooms']]
# Out:
#        price  bedrooms
# 3   604000.0         4
# 4   510000.0         3
# 5  1225000.0         4
# 6   257500.0         3

# %%
houses['bedrooms'].value_counts().iloc[2]
# Out:
# 2760

# %%
houses['bedrooms'].value_counts().loc[33]
# Out:
# 1

# %%
titanic['age'].value_counts().loc['35']
# Out:
# 23

# %%
import pandas as pd
pokemon = pd.read_csv("Pokemon.csv")

# %%
pokemon
# Out:
#      Num        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
pokemon.set_index("Name", inplace=True)

# %%
pokemon
# Out:
#             Num   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur     1    Grass  Poison    318   45      49       49       65
# Ivysaur       2    Grass  Poison    405   60      62       63       80
# Venusaur      3    Grass  Poison    525   80      82       83      100
# Charmander    4     Fire     NaN    309   39      52       43       60
# Charmeleon    5     Fire     NaN    405   58      64       58       80
# ...         ...      ...     ...    ...  ...     ...      ...      ...
# Dratini     147   Dragon     NaN    300   41      64       45       50
# Dragonair   148   Dragon     NaN    420   61      84       65       70
# Dragonite   149   Dragon  Flying    600   91     134       95      100
# Mewtwo      150  Psychic     NaN    680  106     110       90      154
# Mew         151  Psychic     NaN    600  100     100      100      100
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Bulbasaur        65     45      1      False
# ...

# %%
pokemon.sort_values('Attack',ascending=False)
# Out:
#            Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Dragonite  149    Dragon  Flying    600   91     134       95      100
# Rhydon     112    Ground    Rock    485  105     130      120       45
# Flareon    136      Fire     NaN    525   65     130       60       95
# Machamp     68  Fighting     NaN    505   90     130       80       65
# Kingler     99     Water     NaN    475   55     130      115       50
# ...        ...       ...     ...    ...  ...     ...      ...      ...
# Kakuna      14       Bug  Poison    205   45      25       50       25
# Abra        63   Psychic     NaN    310   25      20       15      105
# Metapod     11       Bug     NaN    205   50      20       55       25
# Magikarp   129     Water     NaN    200   20      10       55       15
# Chansey    113    Normal     NaN    450  250       5        5       35
#
#            Sp. Def  Speed  Stage  Legendary
# Name
# Dragonite      100     80      3      False
# ...

# %%
pokemon.sort_values('Num', inplace=True)

# %%
pokemon
# Out:
#             Num   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur     1    Grass  Poison    318   45      49       49       65
# Ivysaur       2    Grass  Poison    405   60      62       63       80
# Venusaur      3    Grass  Poison    525   80      82       83      100
# Charmander    4     Fire     NaN    309   39      52       43       60
# Charmeleon    5     Fire     NaN    405   58      64       58       80
# ...         ...      ...     ...    ...  ...     ...      ...      ...
# Dratini     147   Dragon     NaN    300   41      64       45       50
# Dragonair   148   Dragon     NaN    420   61      84       65       70
# Dragonite   149   Dragon  Flying    600   91     134       95      100
# Mewtwo      150  Psychic     NaN    680  106     110       90      154
# Mew         151  Psychic     NaN    600  100     100      100      100
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Bulbasaur        65     45      1      False
# ...

# %%
pokemon.sort_values(['Total','Attack'], ascending=False)
# Out:
#            Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Mewtwo     150   Psychic     NaN    680  106     110       90      154
# Dragonite  149    Dragon  Flying    600   91     134       95      100
# Mew        151   Psychic     NaN    600  100     100      100      100
# Moltres    146      Fire  Flying    580   90     100       90      125
# Zapdos     145  Electric  Flying    580   90      90       85      125
# ...        ...       ...     ...    ...  ...     ...      ...      ...
# Kakuna      14       Bug  Poison    205   45      25       50       25
# Metapod     11       Bug     NaN    205   50      20       55       25
# Magikarp   129     Water     NaN    200   20      10       55       15
# Weedle      13       Bug  Poison    195   40      35       30       20
# Caterpie    10       Bug     NaN    195   45      30       35       20
#
#            Sp. Def  Speed  Stage  Legendary
# Name
# Mewtwo          90    130      1       True
# ...

# %%
pokemon.sort_index(inplace=True)

# %%
pokemon['Speed'].nlargest(10).mean()
# Out:
# 122.0

# %%
pokemon.sort_values('Attack', ascending=False).head(20)['Type 1'].value_counts()
# Out:
# Type 1
# Fighting    4
# Water       3
# Rock        3
# Fire        2
# Bug         2
# Normal      2
# Dragon      1
# Ground      1
# Psychic     1
# Poison      1
# Name: count, dtype: int64

# %%
pokemon.loc[['Zapdos','Weedle']]
# Out:
#         Num    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Zapdos  145  Electric  Flying    580  90      90       85      125       90
# Weedle   13       Bug  Poison    195  40      35       30       20       20
#
#         Speed  Stage  Legendary
# Name
# Zapdos    100      1       True
# Weedle     50      1      False

# %%
pokemon.loc['Dragonite':'Zapdos']
# Out:
#             Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Dragonite   149    Dragon  Flying    600   91     134       95      100
# Dratini     147    Dragon     NaN    300   41      64       45       50
# Drowzee      96   Psychic     NaN    328   60      48       45       43
# Dugtrio      51    Ground     NaN    405   35      80       50       50
# Eevee       133    Normal     NaN    325   55      55       50       45
# ...         ...       ...     ...    ...  ...     ...      ...      ...
# Weedle       13       Bug  Poison    195   40      35       30       20
# Weepinbell   70     Grass  Poison    390   65      90       50       85
# Weezing     110    Poison     NaN    490   65      90      120       85
# Wigglytuff   40    Normal   Fairy    435  140      70       45       85
# Zapdos      145  Electric  Flying    580   90      90       85      125
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# ...

# %%
pokemon.iloc[[30,40,50]]
# Out:
#           Num  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Eevee     133  Normal     NaN    325  55      55       50       45       65
# Gengar     94   Ghost  Poison    500  60      65       60      130       75
# Gyarados  130   Water  Flying    540  95     125       79       60      100
#
#           Speed  Stage  Legendary
# Name
# Eevee        55      1      False
# Gengar      110      3      False
# Gyarados     81      2      False

# %%
names=['Weepinbell','Weezing','Dratini']
pokemon.loc[names]
# Out:
#             Num  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Weepinbell   70   Grass  Poison    390  65      90       50       85       45
# Weezing     110  Poison     NaN    490  65      90      120       85       70
# Dratini     147  Dragon     NaN    300  41      64       45       50       50
#
#             Speed  Stage  Legendary
# Name
# Weepinbell     55      2      False
# Weezing        60      2      False
# Dratini        50      1      False

# %%
pokemon.loc[names]['Attack'].plot(kind='bar')
# Out:
# <Axes: xlabel='Name'>
