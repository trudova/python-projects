# %%
import pandas as pd
books = pd.read_csv('bestsellers.csv')
books
housing = pd.read_csv('kc_house_data.csv')
titanic = pd.read_csv('titanic.csv')
netflix = pd.read_csv('netflix_titles.csv', sep='|', index_col=0)
coin = pd.read_csv("coin_Bitcoin.csv")
hc = pd.read_csv('world-happiness-report-2021.csv')

# %%
pd.to_datetime('2024-12-31')
# Out:
# Timestamp('2024-12-31 00:00:00')

# %%
pd.to_datetime('2024/12/31')
# Out:
# Timestamp('2024-12-31 00:00:00')

# %%
pd.to_datetime('10/11/12')
# Out:
# Timestamp('2012-10-11 00:00:00')

# %%
pd.to_datetime('10/11/12',dayfirst=True)
# Out:
# Timestamp('2012-11-10 00:00:00')

# %%
pd.to_datetime('10/11/12',yearfirst=True)
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
pd.to_datetime('10/11/12',yearfirst=True, dayfirst=True)
# Out:
# Timestamp('2010-12-11 00:00:00')

# %%
pd.to_datetime('10/11/12',format='%y/%m/%d')
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
ufo = pd.read_csv('nuforc_reports.csv')
ufo
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: float64(2), object(10)
# memory usage: 8.1+ MB

# %%
pd.to_datetime(ufo['date_time'])
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
ufo['dates']=pd.to_datetime(ufo['date_time'])

# %%
ufo.tail()
# Out:
#                                                  summary            city  \
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape    duration  \
# 88120    AZ  2019-10-02T20:00:00  formation   3 minutes
# 88121    MO  2019-10-02T20:00:00      light  20 seconds
# 88122    FL  2019-10-02T20:03:00  formation  20 seconds
# 88123    NC  2019-10-02T22:00:00   fireball   2 minutes
# 88124    CA  2019-10-02T22:00:00     sphere   3 minutes
#
#                                                    stats  \
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# ...

# %%
ufo['date_time']=pd.to_datetime(ufo['date_time'])

# %%
ufo
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufo = pd.read_csv('nuforc_reports.csv', parse_dates=['date_time'])
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufo['date_time'].dt.year.value_counts()
# Out:
# date_time
# 2014.0    8704
# 2012.0    8124
# 2013.0    7823
# 2015.0    6915
# 2019.0    5767
# 2016.0    5664
# 2011.0    5630
# 2008.0    5307
# 2017.0    5057
# 2009.0    4996
# 2010.0    4786
# 2007.0    4736
# 2006.0    3720
# 2018.0    3273
# 2005.0     566
# 2004.0     340
# 1997.0     300
# 2001.0     263
# 2000.0     243
# 2003.0     238
# 1998.0     229
# 2002.0     220
# 1999.0     220
# 1995.0     219
# 1996.0     200
# 1994.0     197
# 1978.0     195
# 1975.0     180
# 1977.0     169
# 1976.0     164
# 1974.0     148
# 1979.0     148
# 1993.0     148
# 1988.0     147
# 1973.0     138
# 1985.0     133
# 1990.0     132
# 1989.0     131
# 1980.0     131
# 1992.0     130
# 1987.0     124
# 1991.0     119
# 1986.0     111
# 1983.0     109
# 1981.0     106
# 1970.0     100
# 1982.0      97
# 1969.0      97
# 1972.0      92
# 1984.0      84
# 1971.0      68
# Name: count, dtype: int64

# %%
ufo['date_time'].dt.year.value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='date_time'>

# %%
ufo['date_time'].dt.month.value_counts()
# Out:
# date_time
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 6.0      8357
# 11.0     7596
# 12.0     6525
# 5.0      6063
# 1.0      5979
# 4.0      5817
# 3.0      5494
# 2.0      4559
# Name: count, dtype: int64

# %%
ufo['date_time'].dt.day.value_counts()
# Out:
# date_time
# 1.0     4852
# 15.0    4403
# 4.0     3864
# 20.0    3016
# 12.0    2945
# 10.0    2923
# 24.0    2831
# 25.0    2805
# 30.0    2793
# 7.0     2776
# 5.0     2755
# 14.0    2739
# 22.0    2723
# 3.0     2708
# 19.0    2681
# 18.0    2678
# 11.0    2639
# 8.0     2635
# 23.0    2634
# 13.0    2634
# 17.0    2607
# 21.0    2602
# 16.0    2598
# 6.0     2578
# 28.0    2555
# 27.0    2531
# 9.0     2443
# 26.0    2430
# 2.0     2425
# 29.0    2364
# 31.0    1771
# Name: count, dtype: int64

# %%
ufo['date_time'].dt.hour.value_counts()
# Out:
# date_time
# 21.0    12851
# 22.0    11660
# 20.0     9565
# 23.0     8194
# 19.0     6460
# 0.0      5577
# 18.0     4462
# 1.0      3285
# 17.0     2660
# 2.0      2216
# 3.0      2088
# 5.0      1874
# 4.0      1641
# 16.0     1612
# 6.0      1588
# 12.0     1408
# 15.0     1380
# 10.0     1334
# 13.0     1308
# 11.0     1301
# 14.0     1280
# 9.0      1126
# 7.0      1067
# 8.0      1001
# Name: count, dtype: int64

# %%
ufo['date_time'].dt.hour.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='date_time'>

# %%
ufo['date_time'].dt.dayofweek.value_counts()
# Out:
# date_time
# 5.0    16305
# 4.0    12864
# 6.0    12652
# 3.0    11729
# 2.0    11646
# 1.0    10987
# 0.0    10755
# Name: count, dtype: int64

# %%
ufo['date_time'] <'1980'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: date_time, Length: 88125, dtype: bool

# %%
ufo[ufo['date_time'] <'1980']
# Out:
#                                                  summary  \
# 8      Ufos report in Irving Texas at 2200 hrs. On or...
# 15        Strange bright light hovered over mobile home.
# 31     Bright green round object quickly travelling e...
# 54     It was a full moon when my brother and I obser...
# 55              UFO over Orangevale, CA in May/June 1969
# ...                                                  ...
# 87166  VERY LARGE OBJECT- WHITE LIGHT ILLUMINATING MY...
# 87167  7 "PEARLESCENT" HIGH ALTITUDE CRAFT IN V FORMA...
# 87168  The even occurred North of Mt Calvary Rd on Ol...
# 87169  Triangle ship passed over silent with 7 green ...
# 87170  While trick or treating with Mom, my Grandma p...
#
#                         city state           date_time     shape  \
# 8                     Dallas    TX 1973-07-14 22:00:00      oval
# 15                Gray Court    SC 1975-07-17 00:00:00     light
# 31     N. Cascades Nat. Park    WA 1979-07-15 23:00:00     light
# ...

# %%
ufo[ufo['date_time'] >'2019-12-23']
# Out:
#                                                  summary        city state  \
# 85714  7-8 elongated objects flying in straight line ...  Wilmington    NC
#
#                 date_time  shape    duration  \
# 85714 2019-12-29 20:40:00  cigar  10 seconds
#
#                                                    stats  \
# 85714  Occurred : 11/29/2019 20:40  (Entered as : 12/...
#
#                                              report_link  \
# 85714  http://www.nuforc.org/webreports/151/S151158.html
#
#                                                     text               posted  \
# 85714  7-8 elongated objects flying in straight line ...  2019-12-01T00:00:00
#
#        city_latitude  city_longitude
# 85714      34.238375      -77.878468

# %%
ufo[ufo['date_time'].dt.hour ==2]
# Out:
#                                                  summary               city  \
# 3      I was driving towards the intersection of fall...             Ottawa
# 14     Bright Circle of Light followed me from Oskalo...        Centerville
# 148                                Strange Vibrations...          Indianola
# 153    red ball ufo following small plane in tracy, c...              Tracy
# 181    Silver disk flies through sky making zigzaggin...          Beaverton
# ...                                                  ...                ...
# 87975  Massive triangle at very low altitude and low ...       Hawkinsville
# 88026  Triangle on fire traveling through the night s...  Panama City Beach
# 88027  At first It looked like a drone but it was mov...        Panama City
# 88056                                     MADAR Node 157          Pensacola
# 88097                             Hovering band of light           Columbia
#
# ...

# %%
ufo[ufo['date_time'].between('2018', '2019')].sort_values('date_time')
# Out:
#                                                  summary            city  \
# 79267               3 Star like crafts in New Years 2018           Miami
# 79266  This event was recorded by the news station wh...         Seattle
# 79265  Several orange lights moving slowly, which fad...     Albuquerque
# 79268  I saw one floating orb while facing north.  Th...  Spokane Valley
# 79269  I was looking out the south window at 12;04AM....  Port Charlotte
# ...                                                  ...             ...
# 84883              Red/ Orange lights - spherical shape.          Spring
# 85377   Green blinking lights zig zag in the sky Florida     Ponte Vedra
# 85095  I saw fiery orange lights no sound flying at l...     San Antonio
# 85111  Observed 6 red lights spaced apart moving slow...        Hamilton
# 85863  See the UFO on Google Maps look for 833 Garfie...        Lansdale
#
#       state           date_time     shape       duration  \
# ...

# %%
ufo[ufo['date_time']>'2019-12-22']
# Out:
#                                                  summary  \
# 3892   Lights in a row.  ((NUFORC Note:  Starlink sat...
# 3893   I saw a very big circle like thing in the sky ...
# 3894   I saw and photographed an object hovering abou...
# 3895   I stepped out back and saw a straight line pro...
# 3896   string of lights evenly spaced moving across s...
# 3897   satellite like looking objects single file lin...
# 3898   OBJECTS APPEAR AS SATELLITES IN FORMATION.  ((...
# 3899   31 UFOs seen traveling SW to NE in a mostly ev...
# 3900   Lights in sky in straight line at satellite he...
# 3901   The objects looked very high altitude.  ((Star...
# 3902   There was a line of very noticeable lights  tr...
# 3903   8 lights flying S to  equal distance from each...
# 3904   The event was already occurring when I became ...
# 3905   As I stood on my balcony, I saw approximately ...
# 3906   String of white lights that disappeared into a...
# ...

# %%
ufo['date_time'].value_counts()
# Out:
# date_time
# 2015-11-07 18:00:00    104
# 2014-07-04 22:00:00     46
# 2010-07-04 22:00:00     37
# 2012-07-04 22:00:00     34
# 2015-07-04 22:00:00     27
#                       ...
# 2011-07-23 23:20:00      1
# 2011-07-23 23:47:00      1
# 2011-07-24 00:00:00      1
# 2011-07-24 00:02:00      1
# 2019-12-12 18:43:00      1
# Name: count, Length: 73122, dtype: int64

# %%
ufo['date_time'].dt.date
# Out:
# 0        2019-12-12
# 1        2019-03-22
# 2               NaT
# 3        2019-04-17
# 4        2009-03-15
#             ...
# 88120    2019-10-02
# 88121    2019-10-02
# 88122    2019-10-02
# 88123    2019-10-02
# 88124    2019-10-02
# Name: date_time, Length: 88125, dtype: object

# %%
ufo['date_time'].dt.date.value_counts()
# Out:
# date_time
# 2015-11-07    290
# 2014-07-04    270
# 2010-07-04    210
# 2012-07-04    200
# 2013-07-04    185
#              ...
# 1980-09-12      1
# 1988-06-13      1
# 1981-07-29      1
# 2004-07-04      1
# 2003-09-07      1
# Name: count, Length: 8351, dtype: int64

# %%
recent =ufo[ufo['date_time'].dt.year>=2018]
recent['date_time'].dt.date.value_counts()
# Out:
# date_time
# 2019-11-11    77
# 2019-05-25    69
# 2019-05-26    67
# 2019-05-24    60
# 2019-07-04    57
#               ..
# 2019-12-29     1
# 2018-02-08     1
# 2019-05-09     1
# 2018-02-04     1
# 2018-02-07     1
# Name: count, Length: 719, dtype: int64

# %%
ufo['posted']= pd.to_datetime(ufo['posted'])

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(8)
# memory usage: 8.1+ MB

# %%
ufo['time_to_report']= ufo['posted'] - ufo['date_time']

# %%
ufo['time_to_report']
# Out:
# 0          9 days 05:17:00
# 1          6 days 05:30:00
# 2                      NaT
# 3          0 days 22:00:00
# 4       3685 days 06:00:00
#                ...
# 88120      1 days 04:00:00
# 88121      1 days 04:00:00
# 88122      1 days 03:57:00
# 88123      1 days 02:00:00
# 88124      1 days 02:00:00
# Name: time_to_report, Length: 88125, dtype: timedelta64[ns]

# %%
ufo.sort_values('time_to_report',ascending=False)
# Out:
#                                                  summary  \
# 86762  An incomplete report given on behalf of anothe...
# 87145                      Strange globe sighting--1969.
# 721    It was July 1969 on a clear summer evening in ...
# 1576   1969 olive branch Mississippi large round ligh...
# 1580   Six bright lights in &quot;V&quot; formation s...
# ...                                                  ...
# 87935  Two bright strobing lights were stationary and...
# 87936  Noticed an uneven, but steady line of craft fl...
# 87937  The stars moved in unison, without breaking fo...
# 87938  White dots in formation just appearing out of ...
# 87939  It can slowly through the gorge about eye leve...
#
#                           city state           date_time      shape  \
# 86762                  El Paso    TX 1969-06-01 00:00:00      other
# 87145             Philadelphia    PA 1969-07-04 01:30:00     sphere
# 721                 New Castle    PA 1969-07-01 21:00:00       disk
# ...

# %%
longest_waits = ufo.sort_values('time_to_report',ascending=False).head(10)
longest_waits['time_to_report'].dt.days/365
# Out:
# 86762    50.583562
# 87145    50.282192
# 721      50.175342
# 1576     50.101370
# 1580     49.972603
# 84984    49.586301
# 83965    49.213699
# 722      49.180822
# 723      49.052055
# 1301     48.967123
# Name: time_to_report, dtype: float64

# %%
ufo['days_befor_reported'] =ufo['time_to_report'].dt.days

# %%
ufo
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
charts = pd.read_csv('billboard_charts.csv',parse_dates=['date'])

# %%
charts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  datetime64[ns]
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 17.6+ MB

# %%
charts['artist'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='artist'>

# %%
charts
# Out:
#              date  rank                                 song  \
# 0      2021-11-06     1                           Easy On Me
# 1      2021-11-06     2                                 Stay
# 2      2021-11-06     3                        Industry Baby
# 3      2021-11-06     4                           Fancy Like
# 4      2021-11-06     5                           Bad Habits
# ...           ...   ...                                  ...
# 330082 1958-08-04    96                        Over And Over
# 330083 1958-08-04    97                     I Believe In You
# 330084 1958-08-04    98                      Little Serenade
# 330085 1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086 1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
charts[charts['rank']==1]
# Out:
#              date  rank                             song  \
# 0      2021-11-06     1                       Easy On Me
# 100    2021-10-30     1                       Easy On Me
# 200    2021-10-23     1                    Industry Baby
# 300    2021-10-16     1                             Stay
# 400    2021-10-09     1                      My Universe
# ...           ...   ...                              ...
# 329587 1958-09-01     1  Nel Blu Dipinto Di Blu (Volaré)
# 329687 1958-08-25     1                      Little Star
# 329787 1958-08-18     1  Nel Blu Dipinto Di Blu (Volaré)
# 329887 1958-08-11     1                 Poor Little Fool
# 329987 1958-08-04     1                 Poor Little Fool
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 100                             Adele       68.0          1               2
# ...

# %%
charts[charts['rank']==1]['artist'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='artist'>

# %%
charts[charts['rank']==1]['song'].value_counts()
# Out:
# song
# Old Town Road                               19
# Despacito                                   16
# One Sweet Day                               16
# Rockstar                                    15
# I'll Make Love To You                       14
#                                             ..
# Then Came You                                1
# You Haven't Done Nothin                      1
# You Ain't Seen Nothing Yet/Free Wheelin'     1
# Whatever Gets You Thru The Night             1
# I'll Take You There                          1
# Name: count, Length: 1104, dtype: int64

# %%
charts[charts['song']=='Old Town Road']
# Out:
#             date  rank           song                               artist  \
# 9445  2020-01-18    46  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9514  2020-01-11    15  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9633  2020-01-04    34  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9740  2019-12-28    41  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9838  2019-12-21    39  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9930  2019-12-14    31  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10019 2019-12-07    20  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10126 2019-11-30    27  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10220 2019-11-23    21  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10317 2019-11-16    18  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10420 2019-11-09    21  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# ...

# %%
charts[charts['song']=='Old Town Road']['rank']
# Out:
# <Axes: >

# %%
charts[charts['song']=='Old Town Road'].set_index('date')['rank'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
p = charts[charts['song']=='Old Town Road'].set_index('date')['rank'].plot()
p.invert_yaxis()
